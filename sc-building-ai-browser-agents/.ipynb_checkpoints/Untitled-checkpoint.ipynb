# %%
# !pwd
# Out:
# /home/jovyan/work

# %%
cd ..
# Out:
# /home/jovyan

# %%
# !pwd
# Out:
# /home/jovyan

# %%
# !ls
# Out:
# work

# %%
# !tar -czvf work.tar.gz work
# Out:
# work/
# work/L2/
# work/L2/L2.ipynb
# work/L2/env.template
# work/L2/helper.py
# work/L2/prompts.py
# work/L2/requirements.txt
# work/L2/.ipynb_checkpoints/
# work/.ipynb_checkpoints/
# work/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# work/Untitled.ipynb
# work/.keep
# work/L3/
# work/L3/L3.ipynb
# work/L3/env.template
# work/L3/helper.py
# work/L3/prompts.py
# work/L3/requirements.txt
# work/L4/
# work/L4/L4.ipynb
# work/L4/env.template
# work/L4/helper.py
# work/L4/prompts.py
# work/L4/requirements.txt
# work/L5/
# work/L5/L5.ipynb
# work/L5/default.sqlite
# work/L5/env.template
# work/L5/helper.py
# work/L5/prompts.py
# work/L5/requirements.txt
# work/L6/
# work/L6/L6.ipynb
# work/L6/default.sqlite
# work/L6/env.template
# work/L6/helper.py
# work/L6/prompts.py
# work/L6/requirements.txt
# work/helper.py
# work/prompts.py
# work/requirements.txt

# %%
# !ls
# Out:
# work  work.tar.gz

# %%
# !cp work.tar.gz work
